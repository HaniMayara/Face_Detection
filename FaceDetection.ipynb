# %% [markdown]
# # 1. Setup and Get Data

# %% [markdown]
# ### 1.1 Install Dependencies and Setup

# %%
# !pip install labelme tensorflow tensorflow-gpu opencv-python matplotlib albumentations

# %% [markdown]
# ### 1.2 Collect Images Using OpenCV

# %%
import os
import time
import uuid
import cv2

# %%
IMAGES_PATH = os.path.join('data','images')
number_images = 30

# %%
cap = cv2.VideoCapture(0)
time.sleep(1)  # Give the camera time to warm up

for imgnum in range(number_images):
    print('Collecting image {}'.format(imgnum))
    ret, frame = cap.read()

    if not ret:
        print("Failed to capture image")
        continue

    # Save the image
    imgname = os.path.join(IMAGES_PATH, f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    print(f"Image saved at {imgname}")
    
    time.sleep(0.5)  # Adjust this as necessary

cap.release()
# Out:
# Collecting image 0
# Image saved at data\images\44a46915-8be7-11ef-a40c-300505360c49.jpg
# Collecting image 1
# Image saved at data\images\44f16f58-8be7-11ef-9b5f-300505360c49.jpg
# Collecting image 2
# Image saved at data\images\453e7cbc-8be7-11ef-a6a7-300505360c49.jpg
# Collecting image 3
# Image saved at data\images\458bafcb-8be7-11ef-bf6f-300505360c49.jpg
# Collecting image 4
# Image saved at data\images\45d8e11a-8be7-11ef-9965-300505360c49.jpg
# Collecting image 5
# Image saved at data\images\4625ea5a-8be7-11ef-9e0d-300505360c49.jpg
# Collecting image 6
# Image saved at data\images\46734125-8be7-11ef-b29c-300505360c49.jpg
# Collecting image 7
# Image saved at data\images\46c0b974-8be7-11ef-817e-300505360c49.jpg
# Collecting image 8
# Image saved at data\images\470de224-8be7-11ef-927c-300505360c49.jpg
# Collecting image 9
# Image saved at data\images\475af5fc-8be7-11ef-b43b-300505360c49.jpg
# Collecting image 10
# Image saved at data\images\47a87951-8be7-11ef-95ec-300505360c49.jpg
# Collecting image 11
# Image saved at data\images\47f5b108-8be7-11ef-96a3-300505360c49.jpg
# Collecting image 12
# Image saved at data\images\4842c1ac-8be7-11ef-bfb4-300505360c49.jpg
# Collecting image 13
# Image saved at data\images\488fc79f-8be7-11ef-879c-300505360c49.jpg
# Collecting image 14
# Image saved at data\images\48dcdb9f-8be7-11ef-8d85-300505360c49.jpg
# Collecting image 15
# Image saved at data\images\492a8910-8be7-11ef-8a94-300505360c49.jpg
# Collecting image 16
# Image saved at data\images\4977beab-8be7-11ef-97b3-300505360c49.jpg
# Collecting image 17
# Image saved at data\images\49c5795e-8be7-11ef-8350-300505360c49.jpg
# Collecting image 18
# Image saved at data\images\4a12bfbf-8be7-11ef-9a29-300505360c49.jpg
# Collecting image 19
# Image saved at data\images\4a6038f2-8be7-11ef-a4df-300505360c49.jpg
# Collecting image 20
# Image saved at data\images\4aad4c7f-8be7-11ef-8370-300505360c49.jpg
# Collecting image 21
# Image saved at data\images\4afb4c5a-8be7-11ef-aa2c-300505360c49.jpg
# Collecting image 22
# Image saved at data\images\4b48c811-8be7-11ef-86af-300505360c49.jpg
# Collecting image 23
# Image saved at data\images\4b95fc1d-8be7-11ef-8800-300505360c49.jpg
# Collecting image 24
# Image saved at data\images\4be32cc9-8be7-11ef-9da5-300505360c49.jpg
# Collecting image 25
# Image saved at data\images\4c304f13-8be7-11ef-9b56-300505360c49.jpg
# Collecting image 26
# Image saved at data\images\4c7dad7f-8be7-11ef-9f39-300505360c49.jpg
# Collecting image 27
# Image saved at data\images\4ccb352e-8be7-11ef-b593-300505360c49.jpg
# Collecting image 28
# Image saved at data\images\4d18ac8d-8be7-11ef-8479-300505360c49.jpg
# Collecting image 29
# Image saved at data\images\4d65e145-8be7-11ef-8989-300505360c49.jpg

# %% [markdown]
# ### 1.3 Annotate Images with LabelMe

# %%
# !labelme
# Out:
# 2024-10-16 22:28:10,970 [INFO   ] __init__:get_config:67- Loading config file from: C:\Users\pc\.labelmerc

# %% [markdown]
# # 2. Review Dataset and Build Image Loading Function

# %% [markdown]
# ### 2.1 Import TF and Deps

# %%
import tensorflow as tf
import json
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### 2.2 Limit GPU Memory Growth

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# ### 2.3 Load Image into TF Data Pipeline

# %%
images = tf.data.Dataset.list_files('data\\images\\*.jpg')

# %%
images.as_numpy_iterator().next()
# Out:
# b'data\\images\\219d21ad-8be7-11ef-ba42-300505360c49.jpg'

# %%
def load_image(x): 
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
images = images.map(load_image)

# %%
images.as_numpy_iterator().next()
# Out:
# array([[[180, 190, 191],
#         [180, 190, 191],
#         [180, 190, 191],
#         ...,
#         [172, 180, 182],
#         [174, 179, 182],
#         [174, 179, 182]],
#
#        [[179, 189, 190],
#         [179, 189, 190],
#         [180, 190, 191],
#         ...,
#         [174, 182, 184],
#         [176, 181, 184],
#         [176, 181, 184]],
#
#        [[180, 189, 188],
#         [181, 190, 189],
#         [182, 191, 190],
#         ...,
#         [177, 182, 185],
#         [177, 182, 185],
#         [177, 182, 185]],
#
#        ...,
#
#        [[ 49,  42,  34],
#         [ 49,  42,  34],
#         [ 48,  41,  33],
#         ...,
#         [ 70,  57,  48],
#         [ 66,  56,  46],
#         [ 64,  54,  44]],
#
#        [[ 50,  41,  36],
#         [ 49,  40,  35],
#         [ 48,  39,  32],
#         ...,
#         [ 64,  54,  45],
#         [ 61,  51,  42],
#         [ 57,  48,  39]],
#
#        [[ 47,  38,  33],
#         [ 47,  38,  33],
#         [ 47,  38,  31],
#         ...,
#         [ 59,  49,  40],
#         [ 55,  46,  39],
#         [ 53,  44,  37]]], dtype=uint8)

# %%
type(images)
# Out:
# tensorflow.python.data.ops.map_op._MapDataset

# %% [markdown]
# ### 2.4 View Raw Images with Matplotlib

# %%
image_generator = images.batch(4).as_numpy_iterator()

# %%
plot_images = image_generator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, image in enumerate(plot_images):
    ax[idx].imshow(image) 
plt.show()

# %% [markdown]
# # 3. Partition Unaugmented Data

# %% [markdown]
# ### 3.1 MANUALLY SPLT DATA INTO TRAIN TEST AND VAL

# %%
90*.7 # 63 to train

# %%
90*.15 # 14 and 13 to test and val

# %% [markdown]
# ### 3.2 Move the Matching Labels

# %%
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):
        
        filename = file.split('.')[0]+'.json'
        existing_filepath = os.path.join('data','labels', filename)
        if os.path.exists(existing_filepath): 
            new_filepath = os.path.join('data',folder,'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# # 4. Apply Image Augmentation on Images and Labels using Albumentations

# %% [markdown]
# ### 4.1 Setup Albumentations Transform Pipeline

# %%
import albumentations as alb

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450), 
                         alb.HorizontalFlip(p=0.5), 
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2), 
                         alb.RGBShift(p=0.2), 
                         alb.VerticalFlip(p=0.5)], 
                       bbox_params=alb.BboxParams(format='albumentations', 
                                                  label_fields=['class_labels']))

# %% [markdown]
# ### 4.2 Load a Test Image and Annotation with OpenCV and JSON

# %%
img = cv2.imread(os.path.join('data','train', 'images','231ff9ad-8be7-11ef-b918-300505360c49.jpg'))

# %%
with open(os.path.join('data', 'train', 'labels', '231ff9ad-8be7-11ef-b918-300505360c49.json'), 'r') as f:
    label = json.load(f)

# %%
label['shapes'][0]['points']
# Out:
# [[405.7487922705314, 84.44444444444443],
#  [298.0193236714976, 256.42512077294685]]

# %% [markdown]
# ### 4.3 Extract Coordinates and Rescale to Match Image Resolution

# %%
plt.imshow(img)

# %%
coords = [0,0,0,0]
coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]

# %%
coords
# Out:
# [405.7487922705314, 84.44444444444443, 298.0193236714976, 256.42512077294685]

# %%
coords = list(np.divide(coords, [640,480,640,480]))

# %%
coords
# Out:
# [0.465655193236715, 0.1759259259259259, 0.6339824879227053, 0.534219001610306]

# %%
fixed_coords = [coords[2], coords[1], coords[0], coords[3]]

print("Fixed coords:", fixed_coords)
# Out:
# Fixed coords: [0.465655193236715, 0.1759259259259259, 0.6339824879227053, 0.534219001610306]

# %%
coords = fixed_coords

# %% [markdown]
# ### 4.4 Apply Augmentations and View Results

# %%
augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])

# %%
augmented['bboxes'][0][2:]
# Out:
# [0.40884592692057287, 0.8523456796010336]

# %%
augmented['bboxes']
# Out:
# [[0.16944714016384543,
#   0.47016637166341146,
#   0.40884592692057287,
#   0.8523456796010336]]

# %%
cv2.rectangle(augmented['image'], 
              tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [450,450]).astype(int)), 
                    (255,0,0), 2)

plt.imshow(augmented['image'])

# %% [markdown]
# # 5. Build and Run Augmentation Pipeline

# %% [markdown]
# ### 5.1 Run Augmentation Pipeline

# %%
for partition in ['train','test','val']: 
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            x1, y1 = label['shapes'][0]['points'][0]
            x2, y2 = label['shapes'][0]['points'][1]

            # Detect min and max for x and y to set [x_min, y_min, x_max, y_max]
            #these steps are not needed if the annotation is done right
            x_min, x_max = min(x1, x2), max(x1, x2)
            y_min, y_max = min(y1, y2), max(y1, y2)
            coords = [x_min, y_min, x_max, y_max]
            
            coords = list(np.divide(coords, [640, 480, 640, 480]))


        try: 
            for x in range(60):
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        annotation['bbox'] = augmented['bboxes'][0]
                        annotation['class'] = 1
                else: 
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0 


                with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)

# %% [markdown]
# ### 5.2 Load Augmented Images to Tensorflow Dataset

# %%
train_images = tf.data.Dataset.list_files('aug_data\\train\\images\\*.jpg', shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))
train_images = train_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('aug_data\\test\\images\\*.jpg', shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('aug_data\\val\\images\\*.jpg', shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/255)

# %%
train_images.as_numpy_iterator().next()
# Out:
# array([[[0.23357843, 0.23357843, 0.22573529],
#         [0.24117647, 0.24117647, 0.23333333],
#         [0.23566176, 0.23566176, 0.22781862],
#         ...,
#         [0.5528799 , 0.54895836, 0.5293505 ],
#         [0.59932595, 0.6026348 , 0.58069855],
#         [0.5965074 , 0.6033701 , 0.57346815]],
#
#        [[0.2026348 , 0.2       , 0.19215687],
#         [0.21807598, 0.21764706, 0.20980392],
#         [0.22071078, 0.22071078, 0.21286765],
#         ...,
#         [0.5745711 , 0.57849264, 0.5554534 ],
#         [0.5995098 , 0.6038603 , 0.5842525 ],
#         [0.60471815, 0.6101103 , 0.5880515 ]],
#
#        [[0.21862745, 0.20294118, 0.19901961],
#         [0.20692402, 0.20300245, 0.19515932],
#         [0.2112745 , 0.20735294, 0.1995098 ],
#         ...,
#         [0.57751226, 0.58143383, 0.561826  ],
#         [0.5900735 , 0.5969363 , 0.578799  ],
#         [0.59295344, 0.5983456 , 0.5762868 ]],
#
#        ...,
#
#        [[0.7640319 , 0.77971816, 0.7757966 ],
#         [0.765625  , 0.7813113 , 0.7773897 ],
#         [0.76164216, 0.78517157, 0.77732843],
#         ...,
#         [0.5206495 , 0.53633577, 0.5324142 ],
#         [0.52457106, 0.54025733, 0.53633577],
#         [0.5181373 , 0.53382355, 0.5348039 ]],
#
#        [[0.7607843 , 0.7764706 , 0.77254903],
#         [0.76819855, 0.7848652 , 0.78045344],
#         [0.76868874, 0.79221815, 0.784375  ],
#         ...,
#         [0.52205884, 0.5446078 , 0.5441176 ],
#         [0.5176471 , 0.5411765 , 0.54019606],
#         [0.5185049 , 0.5414216 , 0.5413603 ]],
#
#        [[0.7583333 , 0.77585787, 0.77101713],
#         [0.7581495 , 0.78903186, 0.7787377 ],
#         [0.76354164, 0.794424  , 0.78707105],
#         ...,
#         [0.5176471 , 0.5485294 , 0.54607844],
#         [0.5175858 , 0.5458946 , 0.54430145],
#         [0.5210784 , 0.54626226, 0.5457108 ]]], dtype=float32)

# %% [markdown]
# # 6. Prepare Labels

# %% [markdown]
# ### 6.1 Build Label Loading Function

# %%
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding = "utf-8") as f:
        label = json.load(f)
        
    return [label['class']], label['bbox']

# %% [markdown]
# ### 6.2 Load Labels to Tensorflow Dataset

# %%
train_labels = tf.data.Dataset.list_files('aug_data\\train\\labels\\*.json', shuffle=False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
test_labels = tf.data.Dataset.list_files('aug_data\\test\\labels\\*.json', shuffle=False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
val_labels = tf.data.Dataset.list_files('aug_data\\val\\labels\\*.json', shuffle=False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
train_labels.as_numpy_iterator().next()
# Out:
# (array([1], dtype=uint8),
#  array([0.5186, 0.5327, 0.7964, 0.879 ], dtype=float16))

# %% [markdown]
# # 7. Combine Label and Image Samples

# %% [markdown]
# ### 7.1 Check Partition Lengths

# %%
len(train_images), len(train_labels), len(test_images), len(test_labels), len(val_images), len(val_labels)
# Out:
# (3840, 3840, 840, 840, 780, 780)

# %% [markdown]
# ### 7.2 Create Final Datasets (Images/Labels)

# %%
train = tf.data.Dataset.zip((train_images, train_labels))
train = train.shuffle(5000)
train = train.batch(8)
train = train.prefetch(4)

# %%
test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(1300)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(1000)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()[1]
# Out:
# (array([[1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1]], dtype=uint8),
#  array([[0.71   , 0.4692 , 0.9233 , 0.7427 ],
#         [0.4507 , 0.     , 0.8726 , 0.583  ],
#         [0.3855 , 0.4946 , 0.5776 , 0.7554 ],
#         [0.988  , 0.0935 , 1.     , 0.4907 ],
#         [0.02362, 0.66   , 0.3843 , 1.     ],
#         [0.     , 0.     , 0.     , 0.     ],
#         [0.4873 , 0.1432 , 0.7266 , 0.5254 ],
#         [0.614  , 0.11444, 0.9614 , 0.663  ]], dtype=float16))

# %% [markdown]
# ### 7.3 View Images and Annotations

# %%
data_samples = train.as_numpy_iterator()

# %%
res = data_samples.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4): 
    sample_image = res[0][idx].copy()
    sample_coords = res[1][1][idx]
    
    cv2.rectangle(sample_image, 
                  tuple(np.multiply(sample_coords[:2], [120,120]).astype(int)),
                  tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)), 
                        (255,0,0), 2)

    ax[idx].imshow(sample_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 8. Build Deep Learning using the Functional API

# %% [markdown]
# ### 8.1 Import Layers and Base Network

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16

# %% [markdown]
# ### 8.2 Download VGG16

# %%
vgg = VGG16(include_top=False)

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 8.3 Build instance of Network

# %%
def build_model(): 
    input_layer = Input(shape=(120,120,3))
    
    vgg = VGG16(include_top=False)(input_layer)

    # Classification Model  
    f1 = GlobalMaxPooling2D()(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)
    
    # Bounding box model
    f2 = GlobalMaxPooling2D()(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)
    
    facetracker = Model(inputs=input_layer, outputs=[class2, regress2])
    return facetracker

# %% [markdown]
# ### 8.4 Test out Neural Network

# %%
facetracker = build_model()

# %%
facetracker.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 120, 120,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 3, 3, 512) │ 14,714,688 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │      2,049 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │      8,196 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,826,181 (64.19 MB)
#  Trainable params: 16,826,181 (64.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X, y = train.as_numpy_iterator().next()

# %%
X.shape
# Out:
# (8, 120, 120, 3)

# %%
classes, coords = facetracker.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step

# %%
classes, coords
# Out:
# (array([[0.5326713 ],
#         [0.47396618],
#         [0.46267644],
#         [0.45966214],
#         [0.48444837],
#         [0.45136502],
#         [0.49069527],
#         [0.44848475]], dtype=float32),
#  array([[0.55812263, 0.77114725, 0.4883018 , 0.49070796],
#         [0.60216033, 0.6589248 , 0.5436307 , 0.41200605],
#         [0.61164176, 0.78252923, 0.57496285, 0.4335342 ],
#         [0.5601156 , 0.720119  , 0.54291975, 0.5203818 ],
#         [0.54607797, 0.7439709 , 0.53971696, 0.546311  ],
#         [0.564662  , 0.66780543, 0.51174486, 0.5378417 ],
#         [0.60209835, 0.5881088 , 0.54158336, 0.48127982],
#         [0.564842  , 0.65616816, 0.5070358 , 0.4968975 ]], dtype=float32))

# %% [markdown]
# # 9. Define Losses and Optimizers

# %% [markdown]
# ### 9.1 Define Optimizer and LR

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75 -1)/batches_per_epoch

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=lr_decay)
# Out:
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\optimizers\base_optimizer.py:34: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %% [markdown]
# ### 9.2 Create Localization Loss and Classification Loss

# %%
def localization_loss(y_true, yhat):            
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))
                  
    h_true = y_true[:,3] - y_true[:,1] 
    w_true = y_true[:,2] - y_true[:,0] 

    h_pred = yhat[:,3] - yhat[:,1] 
    w_pred = yhat[:,2] - yhat[:,0] 
    
    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))
    
    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.BinaryCrossentropy()
regressloss = localization_loss

# %% [markdown]
# ### 9.3 Test out Loss Metrics

# %%
localization_loss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.586359>

# %%
classloss(y[0], classes)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.7317834>

# %%
regressloss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.586359>

# %% [markdown]
# # 10. Train Neural Network

# %% [markdown]
# ### 10.1 Create Custom Model Class

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker,  **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = tf.keras.losses.get(classloss)
        self.lloss = tf.keras.losses.get(localizationloss)
        self.opt = opt

    
    def train_step(self, batch, **kwargs): 
        
        X, y = batch
        
        with tf.GradientTape() as tape: 
            classes, coords = self.model(X, training=True)

            sample_y = tf.ones((8, 1), dtype=tf.float32)  # sample true labels
            sample_pred = tf.ones((8, 1), dtype=tf.float32)  # sample predictions

            try:
                test_loss = self.closs(sample_y, sample_pred)
                print("Loss computation successful, loss value:", test_loss)
            except ValueError as e:
                print("Loss computation error:", e)

            batch_classloss = self.closs(tf.cast(y[0], tf.float32), classes)

            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
            
            total_loss = batch_localizationloss+0.5*batch_classloss
            
            grad = tape.gradient(total_loss, self.model.trainable_variables)
        
        opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}


    
    def test_step(self, batch, **kwargs): 
        X, y = batch
        
        classes, coords = self.model(X, training=False)
    
        batch_classloss = self.closs(tf.cast(y[0], tf.float32), classes)

        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss+0.5*batch_classloss
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
        
    def call(self, X, **kwargs): 
        return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker)

# %%
model.compile(opt, classloss, regressloss)

# %%
for batch in train.take(1):
    X, y = batch
    classes, _ = model.model(X, training=True)  # Directly access the base model's prediction
    try:
        test_loss = model.closs(tf.cast(y[0], tf.float32), classes)
        print("Standalone test_loss value:", test_loss)
    except ValueError as e:
        print("Error during standalone loss computation:", e)
# Out:
# Standalone test_loss value: tf.Tensor(0.73456013, shape=(), dtype=float32)

# %% [markdown]
# ### 10.2 Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
epochs = 10  # Number of epochs
for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    for batch in train:
        with tf.GradientTape() as tape:
            X, y = batch
            classes, coords = model.model(X, training=True)
            class_loss = model.closs(tf.cast(y[0], tf.float32), classes)
            loc_loss = model.lloss(tf.cast(y[1], tf.float32), coords)
            total_loss = loc_loss + 0.5 * class_loss
        
        grads = tape.gradient(total_loss, model.trainable_variables)
        model.opt.apply_gradients(zip(grads, model.trainable_variables))
    print(f"Epoch {epoch+1} loss: {total_loss.numpy()}")
# Out:
# Epoch 1/10
# Epoch 1 loss: 0.06379655003547668
# Epoch 2/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20016\1867892371.py in ?()
#       3     print(f"Epoch {epoch+1}/{epochs}")
#       4     for batch in train:
#       5         with tf.GradientTape() as tape:
#       6             X, y = batch
# ----> 7             classes, coords = model.model(X, training=True)
#       8             class_loss = model.closs(tf.cast(y[0], tf.float32), classes)
#       9             loc_loss = model.lloss(tf.cast(y[1], tf.float32), coords)
#      10             total_loss = loc_loss + 0.5 * class_loss
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     850                     "layers will not see the mask."
#     851                 )
#     852         finally:
#     853             # Destroy call context if we created it
# --> 854             self._maybe_reset_call_context()
#     855         return outputs
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      44             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45                 call_fn,
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#      51         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask)
#     190             masks = self._flatten_to_reference_inputs(mask)
#     191             for x, mask in zip(inputs, masks):
#     192                 if mask is not None:
#     193                     x._keras_mask = mask
# --> 194         outputs = self._run_through_graph(
#     195             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     196         )
#     197         return unpack_singleton(outputs)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn)
#     147                 if any(id(x) not in tensor_dict for x in node.input_tensors):
#     148                     continue  # Node is not computable, try skipping.
#     149
#     150                 args, kwargs = node.arguments.fill_in(tensor_dict)
# --> 151                 outputs = operation_fn(node.operation)(*args, **kwargs)
#     152
#     153                 # Update tensor_dict.
#     154                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     574             and operation._call_has_training_arg
#     575             and training is not None
#     576         ):
#     577             kwargs["training"] = training
# --> 578         return operation(*args, **kwargs)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     850                     "layers will not see the mask."
#     851                 )
#     852         finally:
#     853             # Destroy call context if we created it
# --> 854             self._maybe_reset_call_context()
#     855         return outputs
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      44             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45                 call_fn,
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#      51         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask)
#     190             masks = self._flatten_to_reference_inputs(mask)
#     191             for x, mask in zip(inputs, masks):
#     192                 if mask is not None:
#     193                     x._keras_mask = mask
# --> 194         outputs = self._run_through_graph(
#     195             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     196         )
#     197         return unpack_singleton(outputs)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn)
#     147                 if any(id(x) not in tensor_dict for x in node.input_tensors):
#     148                     continue  # Node is not computable, try skipping.
#     149
#     150                 args, kwargs = node.arguments.fill_in(tensor_dict)
# --> 151                 outputs = operation_fn(node.operation)(*args, **kwargs)
#     152
#     153                 # Update tensor_dict.
#     154                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     574             and operation._call_has_training_arg
#     575             and training is not None
#     576         ):
#     577             kwargs["training"] = training
# --> 578         return operation(*args, **kwargs)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     850                     "layers will not see the mask."
#     851                 )
#     852         finally:
#     853             # Destroy call context if we created it
# --> 854             self._maybe_reset_call_context()
#     855         return outputs
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      44             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45                 call_fn,
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#      51         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\keras\src\layers\convolutional\base_conv.py in ?(self, inputs)
#     230                 bias_shape = (1,) * (self.rank + 1) + (self.filters,)
#     231             else:
#     232                 bias_shape = (1, self.filters) + (1,) * self.rank
#     233             bias = ops.reshape(self.bias, bias_shape)
# --> 234             outputs += bias
#     235
#     236         if self.activation is not None:
#     237             return self.activation(outputs)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\framework\override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\ops\tensor_math_operator_overrides.py in ?(x, y, name)
#      25 def _add_dispatch_factory(x, y, name=None):
#      26   from tensorflow.python.ops import math_ops
#      27
# ---> 28   return math_ops._add_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1691     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    1692   if x.dtype == dtypes.string:
#    1693     return gen_math_ops.add(x, y, name=name)
#    1694   else:
# -> 1695     return gen_math_ops.add_v2(x, y, name=name)
#
# c:\Users\pc\pyver\py3123\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#     478         _ctx, "AddV2", name, x, y)
#     479       return _result
#     480     except _core._NotOkStatusException as e:
#     481       _ops.raise_from_not_ok_status(e, name)
# --> 482     except _core._FallbackException:
#     483       pass
#     484     try:
#     485       return add_v2_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# ### 10.3 Plot Performance

# %%
hist.history

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(hist.history['total_loss'], color='teal', label='loss')
ax[0].plot(hist.history['val_total_loss'], color='orange', label='val loss')
ax[0].title.set_text('Loss')
ax[0].legend()

ax[1].plot(hist.history['class_loss'], color='teal', label='class loss')
ax[1].plot(hist.history['val_class_loss'], color='orange', label='val class loss')
ax[1].title.set_text('Classification Loss')
ax[1].legend()

ax[2].plot(hist.history['regress_loss'], color='teal', label='regress loss')
ax[2].plot(hist.history['val_regress_loss'], color='orange', label='val regress loss')
ax[2].title.set_text('Regression Loss')
ax[2].legend()

plt.show()

# %% [markdown]
# # 11. Make Predictions

# %% [markdown]
# ### 11.1 Make Predictions on Test Set

# %%
test_data = test.as_numpy_iterator()

# %%
test_sample = test_data.next()

# %%
yhat = facetracker.predict(test_sample[0])

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4): 
    sample_image = test_sample[0][idx]
    sample_coords = yhat[1][idx]
    
    if yhat[0][idx] > 0.9:
        cv2.rectangle(sample_image, 
                      tuple(np.multiply(sample_coords[:2], [120,120]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)), 
                            (255,0,0), 2)
    
    ax[idx].imshow(sample_image)

# %% [markdown]
# ### 11.2 Save the Model

# %%
from tensorflow.keras.models import load_model

# %%
facetracker.save('facetracker.h5')

# %%
facetracker = load_model('facetracker.h5')

# %% [markdown]
# ### 11.3 Real Time Detection

# %%
cap = cv2.VideoCapture(1)
while cap.isOpened():
    _ , frame = cap.read()
    frame = frame[50:500, 50:500,:]
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120,120))
    
    yhat = facetracker.predict(np.expand_dims(resized/255,0))
    sample_coords = yhat[1][0]
    
    if yhat[0] > 0.5: 
        # Controls the main rectangle
        cv2.rectangle(frame, 
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)), 
                            (255,0,0), 2)
        # Controls the label rectangle
        cv2.rectangle(frame, 
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int), 
                                    [0,-30])),
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                    [80,0])), 
                            (255,0,0), -1)
        
        # Controls the text rendered
        cv2.putText(frame, 'face', tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                               [0,-5])),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow('EyeTrack', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
